# %% [markdown]
# <a href="https://colab.research.google.com/github/pauarmentaa/Extraccion-de-Caracteristicas/blob/main/ACTIVIDAD_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# !pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %% [markdown]
# ## Agregar el archivo: microretailer_mit_lift_lab.xlsx

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Verificamos información del DataFrame
Micro_Retailer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, _record_id to 235_email
# dtypes: float64(23), int64(2), object(81)
# memory usage: 141.7+ KB

# %%
#Imprimo los primeros 5 registro del dataframe
Micro_Retailer.head()
# Out:
#                              _record_id             _title  \
# 0  dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1  c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
# 2  5bb632b3-41b5-4fb6-a817-b564e8b45a48  November 12, 2022
# 3  6774a0f6-bab4-4a58-bf94-95ad0b7cb438  November 12, 2022
# 4  6cc637fa-3d54-48c7-9499-6de13d0a26aa  November 12, 2022
#
#         _server_updated_at           _updated_by  \
# 0  2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 3  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 4  2022-11-12 22:15:08 UTC  Salomon Abdala Perez
#
#                                        _geometry  _latitude  _longitude  \
# 0   SRID=4326;POINT(-98.233822273 19.0535362706)  19.053536  -98.233822
# 1  SRID=4326;POINT(-98.2341421351 19.0535610353)  19.053561  -98.234142
# 2    SRID=4326;POINT(-98.232299887 19.058654656)  19.058655  -98.232300
# ...

# %%
#Obtengo un análisis univariado de las variables categóricas
tabla_frecuencia=freq_tbl(Micro_Retailer)
# Out:
#                                _record_id  frequency  percentage  \
# 0    dff2998e-af74-4de6-8efd-488aca24e67b          1    0.005848
# 1    53c25f08-1c1b-4c1c-97d5-b45c940735cc          1    0.005848
# 2    af5c48b5-a916-47a6-aacc-1128ea1e728e          1    0.005848
# 3    4790411b-df1d-44f0-a659-6d99e26ae765          1    0.005848
# 4    e70db20a-25db-412b-9a71-7df285c92a3d          1    0.005848
# ..                                    ...        ...         ...
# 166  75bcc709-90ff-4db7-bb82-293f2f72f3ae          1    0.005848
# 167  bd59c8b6-81cb-4698-8cfd-dbab7f01ef21          1    0.005848
# 168  94b1c6bc-1fb8-4895-aacc-c2604dc12b93          1    0.005848
# 169  d9ff4194-657e-4fb4-b5f4-b7e8b350a646          1    0.005848
# 170  bf720ff0-3b7d-47ed-ba49-f5d4bfb7293c          1    0.005848
#
#      cumulative_perc
# 0           0.005848
# 1           0.011696
# 2           0.017544
# 3           0.023392
# 4           0.029240
# ..               ...
# 166         0.976608
# ...

# %%
valores_nulos=Micro_Retailer.isnull().sum()
valores_nulos
# Out:
# _record_id                                0
# _title                                    0
# _server_updated_at                        0
# _updated_by                               0
# _geometry                                 0
#                                        ...
# 234_willingness_participate_workshop     73
# 318_shopkeeper_name                     123
# 319_shopkeepers_last_name               125
# 236_whatsapp                            129
# 235_email                               142
# Length: 106, dtype: int64

# %%
#import pandas as pd
#from google.colab import files

#valores_nulos = Micro_Retailer.isnull().sum()
#valores_nulos.to_csv("valores_nulos.csv")

# Descargar el archivo CSV
#files.download("valores_nulos.csv")

# %% [markdown]
# ## Aplicar métodos para reemplazar valores nulos del dataframe

# %% [markdown]
# Columnas con **NULOS a eliminar**, decidi eliminarlas debido a que como no tienen ningun tipo de información, considero que es lo mejor.
#
# ELIMINAR: pictures_of_shelves_if_possible, 155_sales_registers_used_for, 28_prefered_payment_method, 31_different_prices_payment_method,269_cash_discount, 270_card_extra_charge, 271_card_fee, 272_card_days_receive_money, 273_platform_extra_charge, 274_platform_fee, 275_platform_days_receive_money, 30_payment_methods_large_purchases, 315_frequency_topups, 316_frequency_utility_bills, 62_frequency_only_services,78_number_home_deliveries_week, 77_delivery_timeslots, 79_delivery_vehicle, 278_credit_interest

# %%
columns_to_drop = ['pictures_of_shelves_if_possible', '155_sales_registers_used_for', '28_prefered_payment_method', '31_different_prices_payment_method', '269_cash_discount', '270_card_extra_charge', '271_card_fee', '272_card_days_receive_money', '273_platform_extra_charge', '274_platform_fee', '275_platform_days_receive_money', '30_payment_methods_large_purchases', '315_frequency_topups', '316_frequency_utility_bills', '62_frequency_only_services', '78_number_home_deliveries_week', '77_delivery_timeslots', '79_delivery_vehicle', '278_credit_interest']

Micro_Retailer2 = Micro_Retailer.drop(columns=columns_to_drop)

# %% [markdown]
# Columnas con **NULOS que decidí cambiar a STRING**, esto debido a que por la naturaleza de los datos considero que es mejor ponerlo como "sin información".

# %%
Micro_Retailer2['233_date_establishment'] = Micro_Retailer2['233_date_establishment'].fillna('sin información')
Micro_Retailer2['5_change_store_space_last_year'] = Micro_Retailer2['5_change_store_space_last_year'].fillna('sin información')
Micro_Retailer2['6_change_employees_average_salary_last_year'] = Micro_Retailer2['6_change_employees_average_salary_last_year'].fillna('sin información')
Micro_Retailer2['20_reviews_finances_monthly'] = Micro_Retailer2['20_reviews_finances_monthly'].fillna('sin información')
Micro_Retailer2['49_inventory_records'] = Micro_Retailer2['49_inventory_records'].fillna('sin información')
Micro_Retailer2['18_sales_records'] = Micro_Retailer2['18_sales_records'].fillna('sin información')
Micro_Retailer2['210_sales_channels'] = Micro_Retailer2['210_sales_channels'].fillna('sin información')
Micro_Retailer2['189_payment_methods'] = Micro_Retailer2['189_payment_methods'].fillna('sin información')
Micro_Retailer2['35_interest_rate'] = Micro_Retailer2['35_interest_rate'].fillna('sin información')
Micro_Retailer2['193_sales_planning_tools'] = Micro_Retailer2['193_sales_planning_tools'].fillna('sin información')
Micro_Retailer2['60_services'] = Micro_Retailer2['60_services'].fillna('sin información')
Micro_Retailer2['317_home_deliveries'] = Micro_Retailer2['317_home_deliveries'].fillna('sin información')
Micro_Retailer2['64_comission_services'] = Micro_Retailer2['64_comission_services'].fillna('sin información')
Micro_Retailer2['66_percentaje_services_income'] = Micro_Retailer2['66_percentaje_services_income'].fillna('sin información')
Micro_Retailer2['69_why_not_services'] = Micro_Retailer2['69_why_not_services'].fillna('sin información')
Micro_Retailer2['185_place_orders_suppliers'] = Micro_Retailer2['185_place_orders_suppliers'].fillna('sin información')
Micro_Retailer2['53_special_conditions_suppliers'] = Micro_Retailer2['53_special_conditions_suppliers'].fillna('sin información')
Micro_Retailer2['192_procurement_planning_tools'] = Micro_Retailer2['192_procurement_planning_tools'].fillna('sin información')
Micro_Retailer2['277_payment_method_suppliers'] = Micro_Retailer2['277_payment_method_suppliers'].fillna('sin información')
Micro_Retailer2['56_procurement_changes_pandemic'] = Micro_Retailer2['56_procurement_changes_pandemic'].fillna('sin información')
Micro_Retailer2['279_changes_procurement_pandemic'] = Micro_Retailer2['279_changes_procurement_pandemic'].fillna('sin información')
Micro_Retailer2['158_charact_organize_products_on_shelves'] = Micro_Retailer2['158_charact_organize_products_on_shelves'].fillna('sin información')
Micro_Retailer2['161_actions_stockouts'] = Micro_Retailer2['161_actions_stockouts'].fillna('sin información')
Micro_Retailer2['318_shopkeeper_name'] = Micro_Retailer2['318_shopkeeper_name'].fillna('sin información')
Micro_Retailer2['319_shopkeepers_last_name'] = Micro_Retailer2['319_shopkeepers_last_name'].fillna('sin información')
Micro_Retailer2['236_whatsapp'] = Micro_Retailer2['236_whatsapp'].fillna('sin información')
Micro_Retailer2['235_email'] = Micro_Retailer2['235_email'].fillna('sin información')
Micro_Retailer2["59_willingness_share_sales_data_mse_better_prices"] = Micro_Retailer2["59_willingness_share_sales_data_mse_better_prices"].fillna('sin información')
Micro_Retailer2["33_credit_to_customers"] = Micro_Retailer2["33_credit_to_customers"].fillna('sin información')
Micro_Retailer2["214_customer_relationship_tools"] = Micro_Retailer2["214_customer_relationship_tools"].fillna('sin información')
Micro_Retailer2["186_internet_connection"] = Micro_Retailer2["186_internet_connection"].fillna('sin información')

# %% [markdown]
# Columnas con **NULOS que cambie por MEDIA**, debido a la naturaleza de sus datos ( númericos o cuantitativos) y por el nombre de sus columnas opté porque sea mejor poner la media de esas columnas para sustituir los nulos.
#
# MEDIA: 268_number_fridges, 2_current_permanent_employees, 4_number_permanent_employees_last_year, 103_number_own_fridges, 145_number_direct_competitors, 24_burnout, 276_expected_days_informal_credit, 36_credit_default_rate, 172_supplier_frequency,163_number_high_perishable_products

# %%
Micro_Retailer2["268_number_fridges"] = Micro_Retailer2["268_number_fridges"].fillna(Micro_Retailer2["268_number_fridges"].mean())
Micro_Retailer2["2_current_permanent_employees"] = Micro_Retailer2["2_current_permanent_employees"].fillna(Micro_Retailer2["2_current_permanent_employees"].mean())
Micro_Retailer2["4_number_permanent_employees_last_year"] = Micro_Retailer2["4_number_permanent_employees_last_year"].fillna(Micro_Retailer2["4_number_permanent_employees_last_year"].mean())
Micro_Retailer2["103_number_own_fridges"] = Micro_Retailer2["103_number_own_fridges"].fillna(Micro_Retailer2["103_number_own_fridges"].mean())
Micro_Retailer2["145_number_direct_competitors"] = Micro_Retailer2["145_number_direct_competitors"].fillna(Micro_Retailer2["145_number_direct_competitors"].mean())
Micro_Retailer2["24_burnout"] = Micro_Retailer2["24_burnout"].fillna(Micro_Retailer2["24_burnout"].mean())
Micro_Retailer2["276_expected_days_informal_credit"] = Micro_Retailer2["276_expected_days_informal_credit"].fillna(Micro_Retailer2["276_expected_days_informal_credit"].mean())
Micro_Retailer2["36_credit_default_rate"] = Micro_Retailer2["36_credit_default_rate"].fillna(Micro_Retailer2["36_credit_default_rate"].mean())
Micro_Retailer2["172_supplier_frequency"] = Micro_Retailer2["172_supplier_frequency"].fillna(Micro_Retailer2["172_supplier_frequency"].mean())
Micro_Retailer2["163_number_high_perishable_products"] = Micro_Retailer2["163_number_high_perishable_products"].fillna(Micro_Retailer2["163_number_high_perishable_products"].mean())

# %% [markdown]
# Cambiar **NULOS por BACKWARDFILL**, creo que en esta columna fue lo mejor ya que de esta manera, los valores faltantes se llenarán con la última respuesta verdadera o falsa que se haya registrado.

# %%
Micro_Retailer2["19_tax_id"] = Micro_Retailer2["19_tax_id"].fillna(method="bfill")
Micro_Retailer2["310_burnout"] = Micro_Retailer2["310_burnout"].fillna(method="bfill")
Micro_Retailer2["227_agreement_ecommerce_platforms"] = Micro_Retailer2["227_agreement_ecommerce_platforms"].fillna(method="bfill")
Micro_Retailer2["311_topups"] = Micro_Retailer2["311_topups"].fillna(method="bfill")
Micro_Retailer2["312_payment_of_utilities"] = Micro_Retailer2["312_payment_of_utilities"].fillna(method="bfill")
Micro_Retailer2["313_home_deliveries"] = Micro_Retailer2["313_home_deliveries"].fillna(method="bfill")
Micro_Retailer2["314_reception_delivery_packages"] = Micro_Retailer2["314_reception_delivery_packages"].fillna(method="bfill")
Micro_Retailer2["42_willingness_share_inventory_data_suppliers"] = Micro_Retailer2["42_willingness_share_inventory_data_suppliers"].fillna(method="bfill")
Micro_Retailer2["44_willingness_inventory_management_suppliers"] = Micro_Retailer2["44_willingness_inventory_management_suppliers"].fillna(method="bfill")
Micro_Retailer2["45_willingness_reorder_suppliers"] = Micro_Retailer2["45_willingness_reorder_suppliers"].fillna(method="bfill")
Micro_Retailer2["46_willingness_reorder_suppliers_variety"] = Micro_Retailer2["46_willingness_reorder_suppliers_variety"].fillna(method="bfill")
Micro_Retailer2["47_willingness_reorder_suppliers_lower_prices"] = Micro_Retailer2["47_willingness_reorder_suppliers_lower_prices"].fillna(method="bfill")
Micro_Retailer2["43_willingness_share_sales_data_suppliers"] = Micro_Retailer2["43_willingness_share_sales_data_suppliers"].fillna(method="bfill")
Micro_Retailer2["58_willingness_share_sales_data_mse"] = Micro_Retailer2["58_willingness_share_sales_data_mse"].fillna(method="bfill")
Micro_Retailer2["157_frequency_organize_shelves"] = Micro_Retailer2["157_frequency_organize_shelves"].fillna(method="bfill")
Micro_Retailer2["38_average_margin_profits"] = Micro_Retailer2["38_average_margin_profits"].fillna(method="bfill")
Micro_Retailer2["249_technology_training"] = Micro_Retailer2["249_technology_training"].fillna(method="bfill")
Micro_Retailer2["250_technology_investment_operations"] = Micro_Retailer2["250_technology_investment_operations"].fillna(method="bfill")
Micro_Retailer2["251_technology_investment_customers"] = Micro_Retailer2["251_technology_investment_customers"].fillna(method="bfill")
Micro_Retailer2["254_technology_roadmap"] = Micro_Retailer2["254_technology_roadmap"].fillna(method="bfill")
Micro_Retailer2["260_technology_scalable"] = Micro_Retailer2["260_technology_scalable"].fillna(method="bfill")
Micro_Retailer2["261_technology_organization"] = Micro_Retailer2["261_technology_organization"].fillna(method="bfill")
Micro_Retailer2["262_technology_serve_customers"] = Micro_Retailer2["262_technology_serve_customers"].fillna(method="bfill")
Micro_Retailer2["263_technology_secure_sales"] = Micro_Retailer2["263_technology_secure_sales"].fillna(method="bfill")
Micro_Retailer2["264_technology_budget"] = Micro_Retailer2["264_technology_budget"].fillna(method="bfill")
Micro_Retailer2["267_technology_investment_customer_preferences"] = Micro_Retailer2["267_technology_investment_customer_preferences"].fillna(method="bfill")

# %% [markdown]
# Cambiar **NULOS por FORWARDFILL**, creo que en esta columna fue lo mejor ya que de esta manera, los valores faltantes se llenarán con la última respuesta verdadera o falsa que se haya registrado.

# %%
Micro_Retailer2["249_technology_training"] = Micro_Retailer2["249_technology_training"].fillna(method="ffill")
Micro_Retailer2["250_technology_investment_operations"] = Micro_Retailer2["250_technology_investment_operations"].fillna(method="ffill")
Micro_Retailer2["251_technology_investment_customers"] = Micro_Retailer2["251_technology_investment_customers"].fillna(method="ffill")
Micro_Retailer2["254_technology_roadmap"] = Micro_Retailer2["254_technology_roadmap"].fillna(method="ffill")
Micro_Retailer2["260_technology_scalable"] = Micro_Retailer2["260_technology_scalable"].fillna(method="ffill")
Micro_Retailer2["261_technology_organization"] = Micro_Retailer2["261_technology_organization"].fillna(method="ffill")
Micro_Retailer2["262_technology_serve_customers"] = Micro_Retailer2["262_technology_serve_customers"].fillna(method="ffill")
Micro_Retailer2["263_technology_secure_sales"] = Micro_Retailer2["263_technology_secure_sales"].fillna(method="ffill")
Micro_Retailer2["264_technology_budget"] = Micro_Retailer2["264_technology_budget"].fillna(method="ffill")
Micro_Retailer2["267_technology_investment_customer_preferences"] = Micro_Retailer2["267_technology_investment_customer_preferences"].fillna(method="ffill")
Micro_Retailer2["234_willingness_participate_workshop"] = Micro_Retailer2["234_willingness_participate_workshop"].fillna(method="ffill")
Micro_Retailer2["19_tax_id"] = Micro_Retailer2["19_tax_id"].fillna(method="ffill")
Micro_Retailer2["310_burnout"] = Micro_Retailer2["310_burnout"].fillna(method="ffill")
Micro_Retailer2["162_inventory_extra_space"] = Micro_Retailer2["162_inventory_extra_space"].fillna(method="ffill")
Micro_Retailer2["157_frequency_organize_shelves"] = Micro_Retailer2["157_frequency_organize_shelves"].fillna(method="ffill")
Micro_Retailer2["58_willingness_share_sales_data_mse"] = Micro_Retailer2["58_willingness_share_sales_data_mse"].fillna(method="ffill")
Micro_Retailer2["43_willingness_share_sales_data_suppliers"] = Micro_Retailer2["43_willingness_share_sales_data_suppliers"].fillna(method="ffill")
Micro_Retailer2["47_willingness_reorder_suppliers_lower_prices"] = Micro_Retailer2["47_willingness_reorder_suppliers_lower_prices"].fillna(method="ffill")
Micro_Retailer2["46_willingness_reorder_suppliers_variety"] = Micro_Retailer2["46_willingness_reorder_suppliers_variety"].fillna(method="ffill")
Micro_Retailer2["45_willingness_reorder_suppliers"] = Micro_Retailer2["45_willingness_reorder_suppliers"].fillna(method="ffill")
Micro_Retailer2["44_willingness_inventory_management_suppliers"] = Micro_Retailer2["44_willingness_inventory_management_suppliers"].fillna(method="ffill")
Micro_Retailer2["42_willingness_share_inventory_data_suppliers"] = Micro_Retailer2["42_willingness_share_inventory_data_suppliers"].fillna(method="ffill")
Micro_Retailer2["314_reception_delivery_packages"] = Micro_Retailer2["314_reception_delivery_packages"].fillna(method="ffill")
Micro_Retailer2["313_home_deliveries"] = Micro_Retailer2["313_home_deliveries"].fillna(method="ffill")
Micro_Retailer2["312_payment_of_utilities"] = Micro_Retailer2["312_payment_of_utilities"].fillna(method="ffill")
Micro_Retailer2["311_topups"] = Micro_Retailer2["311_topups"].fillna(method="ffill")
Micro_Retailer2["227_agreement_ecommerce_platforms"] = Micro_Retailer2["227_agreement_ecommerce_platforms"].fillna(method="ffill")
Micro_Retailer2["38_average_margin_profits"] = Micro_Retailer2["38_average_margin_profits"].fillna(method="ffill")

# %%
#Corroboramos NULOS
valores_nulos1=Micro_Retailer2.isnull().sum().sum()
valores_nulos1
# Out:
# 0

# %%
#Identificar valores nulos por columna
valores_nulos2=Micro_Retailer2.isnull().sum()
valores_nulos2
# Out:
# _record_id                              0
# _title                                  0
# _server_updated_at                      0
# _updated_by                             0
# _geometry                               0
#                                        ..
# 234_willingness_participate_workshop    0
# 318_shopkeeper_name                     0
# 319_shopkeepers_last_name               0
# 236_whatsapp                            0
# 235_email                               0
# Length: 87, dtype: int64

# %%
import pandas as pd
from google.colab import files

#valores_nulos2=Micro_Retailer2.isnull().sum()
#valores_nulos2.to_csv("valores_nulos2.csv")

# Descargar el archivo CSV
#files.download("valores_nulos2.csv")

# %% [markdown]
# ## Aplicar métodos (Desviación Estándar o Rango Intercuartílico) para eliminar Outliers del dataframe.

# %% [markdown]
# **Ocuparé Rango Intercuartílico** ya que la distribución de los datos no necesariamente es normal y puede contener valores atípicos que afecten a la media y desviación estándar. El método del IQR es más robusto y se basa en la mediana y el rango intercuartílico para identificar los valores atípicos.

# %%
#SEPARAMOS LAS COLUMNAS CUANTITATIVAS DEL DATA2
import pandas as pd
# Verificar los tipos de datos de cada columna
print(Micro_Retailer2.dtypes)
# Seleccionar las variables numéricas
data_num = Micro_Retailer2.select_dtypes(include="number")
# Mostrar el DataFrame resultante
print(data_num)
# Out:
# _record_id                              object
# _title                                  object
# _server_updated_at                      object
# _updated_by                             object
# _geometry                               object
#                                          ...
# 234_willingness_participate_workshop    object
# 318_shopkeeper_name                     object
# 319_shopkeepers_last_name               object
# 236_whatsapp                            object
# 235_email                               object
# Length: 87, dtype: object
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0    19.053536  -98.233822                                2
# 1    19.053561  -98.234142                                0
# 2    19.058655  -98.232300                                0
# 3    19.059293  -98.233158                                0
# 4    19.059585  -98.233864                                0
# ...

# %%
data_num.info()
#nos damos cuenta que son numericas por el dtype 
#float64 e int64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 14 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   _latitude                                          171 non-null    float64
#  1   _longitude                                         171 non-null    float64
#  2   97_number_of_customers_in_store                    171 non-null    int64
#  3   268_number_fridges                                 171 non-null    float64
#  4   104_how_many_shelves_does_the_micro_retailer_have  171 non-null    int64
#  5   2_current_permanent_employees                      171 non-null    float64
#  6   4_number_permanent_employees_last_year             171 non-null    float64
#  7   103_number_own_fridges                             171 non-null    float64
# ...

# %%
data_num.head()
# Out:
#    _latitude  _longitude  97_number_of_customers_in_store  268_number_fridges  \
# 0  19.053536  -98.233822                                2                 0.0
# 1  19.053561  -98.234142                                0                 4.0
# 2  19.058655  -98.232300                                0                 0.0
# 3  19.059293  -98.233158                                0                 0.0
# 4  19.059585  -98.233864                                0                 0.0
#
#    104_how_many_shelves_does_the_micro_retailer_have  \
# 0                                                  4
# 1                                                  8
# 2                                                 24
# 3                                                  2
# 4                                                 16
#
#    2_current_permanent_employees  4_number_permanent_employees_last_year  \
# 0                            2.0                                     2.0
# ...

# %%
data_num2=data_num.copy()

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
data_num2.plot(kind='box', vert=False)
plt.title("Valores Atípicos de Girona_España")
plt.show() #dibujamos el diagrama

# %%
#Encuentro cuartiles 0.25 y 0.75
y=data_num2

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
# Out:
# Limite superior permitido _latitude                                            19.138774
# _longitude                                          -98.075320
# 97_number_of_customers_in_store                       5.000000
# 268_number_fridges                                    5.000000
# 104_how_many_shelves_does_the_micro_retailer_have    16.000000
# 2_current_permanent_employees                         3.657658
# 4_number_permanent_employees_last_year                3.263158
# 103_number_own_fridges                                2.518519
# 145_number_direct_competitors                         6.696602
# 24_burnout                                            4.184211
# 276_expected_days_informal_credit                    14.208333
# 36_credit_default_rate                                1.642857
# 172_supplier_frequency                                4.430556
# 163_number_high_perishable_products                  18.602564
# dtype: float64

# %%
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite inferior permitido _latitude                                            18.950047
# _longitude                                          -98.355995
# 97_number_of_customers_in_store                      -3.000000
# 268_number_fridges                                   -3.000000
# 104_how_many_shelves_does_the_micro_retailer_have    -8.000000
# 2_current_permanent_employees                        -0.594595
# 4_number_permanent_employees_last_year               -0.357895
# 103_number_own_fridges                                2.518519
# 145_number_direct_competitors                        -0.817961
# 24_burnout                                            4.184211
# 276_expected_days_informal_credit                    14.208333
# 36_credit_default_rate                                1.642857
# 172_supplier_frequency                                0.541667
# 163_number_high_perishable_products                  -7.961538
# dtype: float64

# %%
#Encontramos Outliers del Dataframe
outliers= data_num2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers
# Out:
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0          NaN         NaN                              NaN
# 1          NaN         NaN                              NaN
# 2          NaN         NaN                              NaN
# 3          NaN         NaN                              NaN
# 4          NaN         NaN                              NaN
# ..         ...         ...                              ...
# 166        NaN         NaN                              NaN
# 167        NaN         NaN                              NaN
# 168        NaN         NaN                              NaN
# 169        NaN         NaN                              NaN
# 170        NaN         NaN                              NaN
#
#      268_number_fridges  104_how_many_shelves_does_the_micro_retailer_have  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# ...

# %%
#Obtenemos datos limpios del Dataframe
data3= data_num2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3
# Out:
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0    19.053536  -98.233822                              2.0
# 1    19.053561  -98.234142                              0.0
# 2    19.058655  -98.232300                              0.0
# 3    19.059293  -98.233158                              0.0
# 4    19.059585  -98.233864                              0.0
# ..         ...         ...                              ...
# 166  19.043115  -98.194066                              1.0
# 167  19.042794  -98.193802                              1.0
# 168  19.042809  -98.193439                              3.0
# 169  19.042558  -98.193818                              0.0
# 170  19.042823  -98.193735                              1.0
#
#      268_number_fridges  104_how_many_shelves_does_the_micro_retailer_have  \
# 0                   0.0                                                4.0
# 1                   4.0                                                8.0
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# _latitude                                             0
# _longitude                                            0
# 97_number_of_customers_in_store                       5
# 268_number_fridges                                   10
# 104_how_many_shelves_does_the_micro_retailer_have     9
# 2_current_permanent_employees                        15
# 4_number_permanent_employees_last_year               12
# 103_number_own_fridges                               27
# 145_number_direct_competitors                        15
# 24_burnout                                           38
# 276_expected_days_informal_credit                    24
# 36_credit_default_rate                               14
# 172_supplier_frequency                               18
# 163_number_high_perishable_products                  17
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data4=data3.copy()
data4=data4.fillna(round(data3.mean(),1))
data4
# Out:
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0    19.053536  -98.233822                              2.0
# 1    19.053561  -98.234142                              0.0
# 2    19.058655  -98.232300                              0.0
# 3    19.059293  -98.233158                              0.0
# 4    19.059585  -98.233864                              0.0
# ..         ...         ...                              ...
# 166  19.043115  -98.194066                              1.0
# 167  19.042794  -98.193802                              1.0
# 168  19.042809  -98.193439                              3.0
# 169  19.042558  -98.193818                              0.0
# 170  19.042823  -98.193735                              1.0
#
#      268_number_fridges  104_how_many_shelves_does_the_micro_retailer_have  \
# 0                   0.0                                                4.0
# 1                   4.0                                                8.0
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(15, 8))
plt.boxplot(data4) 
plt.title("Outliers de Girona_España")
plt.show() #dibujamos el diagrama

# %%
Micro_Retailer2.select_dtypes(include=['object'])
# Out:
#                                _record_id             _title  \
# 0    dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1    c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
# 2    5bb632b3-41b5-4fb6-a817-b564e8b45a48  November 12, 2022
# 3    6774a0f6-bab4-4a58-bf94-95ad0b7cb438  November 12, 2022
# 4    6cc637fa-3d54-48c7-9499-6de13d0a26aa  November 12, 2022
# ..                                    ...                ...
# 166  2413f06e-15cc-4a6f-8e83-5224c6824b12   November 3, 2022
# 167  962bf5a6-1eff-4874-a627-9cd8e3ca27b4   November 3, 2022
# 168  9ff658db-4dc5-48b6-aa0b-5c6668bb6720   November 3, 2022
# 169  e88aa9c1-dc8b-4180-99a1-2e0118ad905d   November 3, 2022
# 170  bf720ff0-3b7d-47ed-ba49-f5d4bfb7293c   November 3, 2022
#
#           _server_updated_at           _updated_by  \
# 0    2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1    2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2    2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# ...

# %%
Micro_Retailer2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 87 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   _record_id                                                  171 non-null    object
#  1   _title                                                      171 non-null    object
#  2   _server_updated_at                                          171 non-null    object
#  3   _updated_by                                                 171 non-null    object
#  4   _geometry                                                   171 non-null    object
#  5   _latitude                                                   171 non-null    float64
#  6   _longitude                                                  171 non-null    float64
# ...

# %%
cuali = Micro_Retailer2.select_dtypes(include=['object'])
Datos_limpios = pd.concat([cuali, data4], axis=1)
Datos_limpios.head()
# Out:
#                              _record_id             _title  \
# 0  dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1  c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
# 2  5bb632b3-41b5-4fb6-a817-b564e8b45a48  November 12, 2022
# 3  6774a0f6-bab4-4a58-bf94-95ad0b7cb438  November 12, 2022
# 4  6cc637fa-3d54-48c7-9499-6de13d0a26aa  November 12, 2022
#
#         _server_updated_at           _updated_by  \
# 0  2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 3  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 4  2022-11-12 22:15:08 UTC  Salomon Abdala Perez
#
#                                        _geometry          228_store_name  \
# 0   SRID=4326;POINT(-98.233822273 19.0535362706)     Eugene’s Compostura
# 1  SRID=4326;POINT(-98.2341421351 19.0535610353)  Frutas y verduras Angy
# 2    SRID=4326;POINT(-98.232299887 19.058654656)               Libélula
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Datos_limpios.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %%
import pandas as pd
from google.colab import files
#cuali = Micro_Retailer2.select_dtypes(include=['object'])
#Datos_limpios = pd.concat([cuali, data4], axis=1)
#Datos_limpios.head()

Datos_limpios.to_csv("Datos_limpios.csv")

# Descargar el archivo CSV
files.download("Datos_limpios.csv")

# %% [markdown]
# ## Extraer características a partir de aplicar un análisis univariado, a diferentes variables categóricas (20). Mostrar los resultados obtenidos ,mediante gráficas y tablas

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Datos_limpios)
# Out:
#                                _record_id  frequency  percentage  \
# 0    dff2998e-af74-4de6-8efd-488aca24e67b          1    0.005848
# 1    53c25f08-1c1b-4c1c-97d5-b45c940735cc          1    0.005848
# 2    af5c48b5-a916-47a6-aacc-1128ea1e728e          1    0.005848
# 3    4790411b-df1d-44f0-a659-6d99e26ae765          1    0.005848
# 4    e70db20a-25db-412b-9a71-7df285c92a3d          1    0.005848
# ..                                    ...        ...         ...
# 166  75bcc709-90ff-4db7-bb82-293f2f72f3ae          1    0.005848
# 167  bd59c8b6-81cb-4698-8cfd-dbab7f01ef21          1    0.005848
# 168  94b1c6bc-1fb8-4895-aacc-c2604dc12b93          1    0.005848
# 169  d9ff4194-657e-4fb4-b5f4-b7e8b350a646          1    0.005848
# 170  bf720ff0-3b7d-47ed-ba49-f5d4bfb7293c          1    0.005848
#
#      cumulative_perc
# 0           0.005848
# 1           0.011696
# 2           0.017544
# 3           0.023392
# 4           0.029240
# ..               ...
# 166         0.976608
# ...

# %% [markdown]
# ### **VARIABLE 1 : 214_customer_relationship_tools**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_232 = Datos_limpios['232_type_of_store']

# Imprimir la columna
print(columna_232)
# Out:
# 0                               Tailor
# 1       Grocery store (aka. nanostore)
# 2       Grocery store (aka. nanostore)
# 3       Grocery store (aka. nanostore)
# 4       Grocery store (aka. nanostore)
#                     ...
# 166     Grocery store (aka. nanostore)
# 167     Grocery store (aka. nanostore)
# 168    Micro-restaurant (aka. fondita)
# 169    Micro-restaurant (aka. fondita)
# 170    Micro-restaurant (aka. fondita)
# Name: 232_type_of_store, Length: 171, dtype: object

# %%
columna_232_sin_nulos=columna_232.isnull().sum()
columna_232_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Datos_limpios['232_type_of_store'])
table1
# Out:
#                   232_type_of_store  frequency  percentage  cumulative_perc
# 0    Grocery store (aka. nanostore)         52    0.304094         0.304094
# 1   Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# 2                    Dairy products         10    0.058480         0.543860
# 3                         Cafeteria          6    0.035088         0.578947
# 4                      Butcher shop          6    0.035088         0.614035
# ..                              ...        ...         ...              ...
# 59                          joyeria          1    0.005848         0.976608
# 60                         dulceria          1    0.005848         0.982456
# 61                             Ropa          1    0.005848         0.988304
# 62                       Ferretería          1    0.005848         0.994152
# 63         productos tradicionales           1    0.005848         1.000000
#
# [64 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
# Out:
#                  232_type_of_store  frequency  percentage  cumulative_perc
# 0   Grocery store (aka. nanostore)         52    0.304094         0.304094
# 1  Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# 2                   Dairy products         10    0.058480         0.543860
# 3                        Cafeteria          6    0.035088         0.578947
# 4                     Butcher shop          6    0.035088         0.614035
# 5    Produce (fruits & vegetables)          4    0.023392         0.637427
# 6               Handmade products           2    0.011696         0.649123
# 7                       Papelería           2    0.011696         0.660819
# 8                         objetos           2    0.011696         0.672515
# 9                      Ferretería           2    0.011696         0.684211

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('232_type_of_store')
Filtro_index
# Out:
#                                  frequency  percentage  cumulative_perc
# 232_type_of_store
# Grocery store (aka. nanostore)          52    0.304094         0.304094
# Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# Dairy products                          10    0.058480         0.543860
# Cafeteria                                6    0.035088         0.578947
# Butcher shop                             6    0.035088         0.614035
# Produce (fruits & vegetables)            4    0.023392         0.637427
# Handmade products                        2    0.011696         0.649123
# Papelería                                2    0.011696         0.660819
# objetos                                  2    0.011696         0.672515
# Ferretería                               2    0.011696         0.684211

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='232_type_of_store'>

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ### **VARIABLE 2 : 184_store_devices**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_184 = Datos_limpios['184_store_devices']

# Imprimir la columna
print(columna_184)
# Out:
# 0      POS system (i.e. computer + bar code scanner +...
# 1                         Dataphone (i.e. card payments)
# 2      Dataphone (i.e. card payments),POS system (i.e...
# 3      POS system (i.e. computer + bar code scanner +...
# 4                                             Smartphone
#                              ...
# 166                      Analog cash register,Smartphone
# 167                      Analog cash register,Smartphone
# 168                                           Smartphone
# 169                                 Analog cash register
# 170                                           Smartphone
# Name: 184_store_devices, Length: 171, dtype: object

# %%
#Obtengo un análisis univariado de una variable categórica en específico
tabla2= freq_tbl(Datos_limpios['184_store_devices'])
tabla2
# Out:
#                                     184_store_devices  frequency  percentage  \
# 0                                          Smartphone         52    0.304094
# 1                                Analog cash register         16    0.093567
# 2   POS system (i.e. computer + bar code scanner +...          9    0.052632
# 3   POS system (i.e. computer + bar code scanner +...          9    0.052632
# 4                     Analog cash register,Smartphone          8    0.046784
# 5                         Security cameras,Smartphone          7    0.040936
# 6   Dataphone (i.e. card payments),Security camera...          5    0.029240
# 7                                    Security cameras          5    0.029240
# 8   POS system (i.e. computer + bar code scanner +...          4    0.023392
# 9               Analog cash register,Security cameras          4    0.023392
# 10   Analog cash register,Security cameras,Smartphone          4    0.023392
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= tabla2[tabla2['frequency']>1]
Filtro
# Out:
#                                     184_store_devices  frequency  percentage  \
# 0                                          Smartphone         52    0.304094
# 1                                Analog cash register         16    0.093567
# 2   POS system (i.e. computer + bar code scanner +...          9    0.052632
# 3   POS system (i.e. computer + bar code scanner +...          9    0.052632
# 4                     Analog cash register,Smartphone          8    0.046784
# 5                         Security cameras,Smartphone          7    0.040936
# 6   Dataphone (i.e. card payments),Security camera...          5    0.029240
# 7                                    Security cameras          5    0.029240
# 8   POS system (i.e. computer + bar code scanner +...          4    0.023392
# 9               Analog cash register,Security cameras          4    0.023392
# 10   Analog cash register,Security cameras,Smartphone          4    0.023392
# ...

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('184_store_devices')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# 184_store_devices
# Smartphone                                                 52    0.304094
# Analog cash register                                       16    0.093567
# POS system (i.e. computer + bar code scanner + ...          9    0.052632
# POS system (i.e. computer + bar code scanner + ...          9    0.052632
# Analog cash register,Smartphone                             8    0.046784
# Security cameras,Smartphone                                 7    0.040936
# Dataphone (i.e. card payments),Security cameras...          5    0.029240
# Security cameras                                            5    0.029240
# POS system (i.e. computer + bar code scanner + ...          4    0.023392
# Analog cash register,Security cameras                       4    0.023392
# Analog cash register,Security cameras,Smartphone            4    0.023392
# ...

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Dispositvos con los que cuenta la tienda')
plt.xlabel('store_devices')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ### **VARIABLE 3 : _updated_by**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
updated_by = Datos_limpios['_updated_by']

# Imprimir la columna
print(updated_by)
# Out:
# 0      Salomon Abdala Perez
# 1      Salomon Abdala Perez
# 2      Salomon Abdala Perez
# 3      Salomon Abdala Perez
# 4      Salomon Abdala Perez
#                ...
# 166            Emilio Garza
# 167            Emilio Garza
# 168            Emilio Garza
# 169          Francisco Adán
# 170            Emilio Garza
# Name: _updated_by, Length: 171, dtype: object

# %%
updated_by_sin_nulos=updated_by.isnull().sum()
updated_by_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table3= freq_tbl(Datos_limpios['_updated_by'])
table3
# Out:
#                           _updated_by  frequency  percentage  cumulative_perc
# 0                Salomon Abdala Perez         20    0.116959         0.116959
# 1   Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# 2                         José Zapata         14    0.081871         0.292398
# 3                        Emilio Garza         13    0.076023         0.368421
# 4                    Benjamin Barbosa         13    0.076023         0.444444
# 5                     Pedro Contreras         12    0.070175         0.514620
# 6                      Eduardo Zárate          9    0.052632         0.567251
# 7                    Alejandro Matias          8    0.046784         0.614035
# 8                     Harry Hernández          7    0.040936         0.654971
# 9                      Francisco Adán          7    0.040936         0.695906
# 10                      Hiram Jiménez          6    0.035088         0.730994
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table3[table3['frequency']>1]
Filtro
# Out:
#                           _updated_by  frequency  percentage  cumulative_perc
# 0                Salomon Abdala Perez         20    0.116959         0.116959
# 1   Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# 2                         José Zapata         14    0.081871         0.292398
# 3                        Emilio Garza         13    0.076023         0.368421
# 4                    Benjamin Barbosa         13    0.076023         0.444444
# 5                     Pedro Contreras         12    0.070175         0.514620
# 6                      Eduardo Zárate          9    0.052632         0.567251
# 7                    Alejandro Matias          8    0.046784         0.614035
# 8                     Harry Hernández          7    0.040936         0.654971
# 9                      Francisco Adán          7    0.040936         0.695906
# 10                      Hiram Jiménez          6    0.035088         0.730994
# ...

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('_updated_by')
Filtro_index
# Out:
#                                    frequency  percentage  cumulative_perc
# _updated_by
# Salomon Abdala Perez                      20    0.116959         0.116959
# Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# José Zapata                               14    0.081871         0.292398
# Emilio Garza                              13    0.076023         0.368421
# Benjamin Barbosa                          13    0.076023         0.444444
# Pedro Contreras                           12    0.070175         0.514620
# Eduardo Zárate                             9    0.052632         0.567251
# Alejandro Matias                           8    0.046784         0.614035
# Harry Hernández                            7    0.040936         0.654971
# Francisco Adán                             7    0.040936         0.695906
# Hiram Jiménez                              6    0.035088         0.730994
# ...

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Encargado de actualizar la base de datos')
plt.xlabel('Nombre de la persona')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='_updated_by'>

# %% [markdown]
# ### **VARIABLE 4 : 5_change_store_space_last_year**

# %%
import pandas as pd

# Seleccionar la columna 5_change_store_space_last_year
columna_5 = Datos_limpios['5_change_store_space_last_year']

# Imprimir la columna
print(columna_5)
# Out:
# 0            No cambió
# 1          Aumentó 15%
# 2            No cambió
# 3            No cambió
# 4            No cambió
#             ...
# 166    sin información
# 167    sin información
# 168    sin información
# 169    sin información
# 170    sin información
# Name: 5_change_store_space_last_year, Length: 171, dtype: object

# %%
columna_5_sin_nulos=columna_5.isnull().sum()
columna_5_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table4= freq_tbl(Datos_limpios['5_change_store_space_last_year'])
table4
# Out:
#   5_change_store_space_last_year  frequency  percentage  cumulative_perc
# 0                      No cambió         72    0.421053         0.421053
# 1                sin información         72    0.421053         0.842105
# 2                  Disminuyó 15%          9    0.052632         0.894737
# 3                    Aumentó 25%          7    0.040936         0.935673
# 4                    Aumentó 15%          4    0.023392         0.959064
# 5              Aumentó 50% o más          4    0.023392         0.982456
# 6                  Disminuyó 25%          2    0.011696         0.994152
# 7            Disminuyó 50% o más          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table4[table4['frequency']>1]
Filtro
# Out:
#   5_change_store_space_last_year  frequency  percentage  cumulative_perc
# 0                      No cambió         72    0.421053         0.421053
# 1                sin información         72    0.421053         0.842105
# 2                  Disminuyó 15%          9    0.052632         0.894737
# 3                    Aumentó 25%          7    0.040936         0.935673
# 4                    Aumentó 15%          4    0.023392         0.959064
# 5              Aumentó 50% o más          4    0.023392         0.982456
# 6                  Disminuyó 25%          2    0.011696         0.994152

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('5_change_store_space_last_year')
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 5_change_store_space_last_year
# No cambió                              72    0.421053         0.421053
# sin información                        72    0.421053         0.842105
# Disminuyó 15%                           9    0.052632         0.894737
# Aumentó 25%                             7    0.040936         0.935673
# Aumentó 15%                             4    0.023392         0.959064
# Aumentó 50% o más                       4    0.023392         0.982456
# Disminuyó 25%                           2    0.011696         0.994152

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ### **VARIABLE 5 : 20_reviews_finances_monthly**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_20 = Datos_limpios['20_reviews_finances_monthly']

# Imprimir la columna
print(columna_20)
# Out:
# 0                  yes
# 1                  yes
# 2                  yes
# 3                  yes
# 4                  yes
#             ...
# 166    sin información
# 167    sin información
# 168    sin información
# 169    sin información
# 170    sin información
# Name: 20_reviews_finances_monthly, Length: 171, dtype: object

# %%
columna_20_sin_nulos=columna_20.isnull().sum()
columna_20_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table5= freq_tbl(Datos_limpios['20_reviews_finances_monthly'])
table5
# Out:
#   20_reviews_finances_monthly  frequency  percentage  cumulative_perc
# 0                         yes         79    0.461988         0.461988
# 1             sin información         63    0.368421         0.830409
# 2                          no         29    0.169591         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table5[table5['frequency']>1]
Filtro
# Out:
#   20_reviews_finances_monthly  frequency  percentage  cumulative_perc
# 0                         yes         79    0.461988         0.461988
# 1             sin información         63    0.368421         0.830409
# 2                          no         29    0.169591         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('20_reviews_finances_monthly')
Filtro_index
# Out:
#                              frequency  percentage  cumulative_perc
# 20_reviews_finances_monthly
# yes                                 79    0.461988         0.461988
# sin información                     63    0.368421         0.830409
# no                                  29    0.169591         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ### **VARIABLE 6 : 49_inventory_records**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_49 = Datos_limpios['49_inventory_records']

# Imprimir la columna
print(columna_49)
# Out:
# 0      Software especializado + computadora
# 1                                No lo hago
# 2                                  En Excel
# 3      Software especializado + computadora
# 4                                  En papel
#                        ...
# 166                         sin información
# 167                         sin información
# 168                         sin información
# 169                         sin información
# 170                         sin información
# Name: 49_inventory_records, Length: 171, dtype: object

# %%
columna_49_sin_nulos=columna_49.isnull().sum()
columna_49_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table6= freq_tbl(Datos_limpios["49_inventory_records"])
table6
# Out:
#                                 49_inventory_records  frequency  percentage  \
# 0                                    sin información         61    0.356725
# 1                                           En papel         40    0.233918
# 2               Software especializado + computadora         21    0.122807
# 3                                           En Excel         20    0.116959
# 4                                         No lo hago         18    0.105263
# 5                                  En Excel,En papel          7    0.040936
# 6                                        Mentalmente          1    0.005848
# 7           Aplicación móvil (i.e. App) + smartphone          1    0.005848
# 8                                    En papel,Mental          1    0.005848
# 9  Aplicación móvil (i.e. App) + smartphone,En Excel          1    0.005848
#
#    cumulative_perc
# 0         0.356725
# 1         0.590643
# 2         0.713450
# 3         0.830409
# 4         0.935673
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table6[table6['frequency']>1]
Filtro
# Out:
#                    49_inventory_records  frequency  percentage  \
# 0                       sin información         61    0.356725
# 1                              En papel         40    0.233918
# 2  Software especializado + computadora         21    0.122807
# 3                              En Excel         20    0.116959
# 4                            No lo hago         18    0.105263
# 5                     En Excel,En papel          7    0.040936
#
#    cumulative_perc
# 0         0.356725
# 1         0.590643
# 2         0.713450
# 3         0.830409
# 4         0.935673
# 5         0.976608

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('49_inventory_records')
Filtro_index
# Out:
#                                       frequency  percentage  cumulative_perc
# 49_inventory_records
# sin información                              61    0.356725         0.356725
# En papel                                     40    0.233918         0.590643
# Software especializado + computadora         21    0.122807         0.713450
# En Excel                                     20    0.116959         0.830409
# No lo hago                                   18    0.105263         0.935673
# En Excel,En papel                             7    0.040936         0.976608

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('En donde realizan los registros de inventario')
plt.xlabel('inventory_records')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
Filtro_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ### **VARIABLE 7 : 18_sales_records**

# %%
import pandas as pd

# Seleccionar la columna 18_sales_records
columna_7 = Datos_limpios["18_sales_records"]

# Imprimir la columna
print(columna_7)
# Out:
# 0      Software especializado + computadora
# 1                                No lo hago
# 2      Software especializado + computadora
# 3      Software especializado + computadora
# 4                                  En papel
#                        ...
# 166                         sin información
# 167                         sin información
# 168                         sin información
# 169                         sin información
# 170                         sin información
# Name: 18_sales_records, Length: 171, dtype: object

# %%
columna_7_sin_nulos=columna_7.isnull().sum()
columna_7_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table8= freq_tbl(Datos_limpios['18_sales_records'])
table8
# Out:
#                                      18_sales_records  frequency  percentage  \
# 0                                     sin información         61    0.356725
# 1                                            En papel         47    0.274854
# 2                Software especializado + computadora         22    0.128655
# 3                                          No lo hago         14    0.081871
# 4                                            En Excel         10    0.058480
# 5                         Caja registradora (análoga)          4    0.023392
# 6                                   En Excel,En papel          4    0.023392
# 7            Aplicación móvil (i.e. App) + smartphone          1    0.005848
# 8   Aplicación móvil (i.e. App) + smartphone,Caja ...          1    0.005848
# 9                                           Contadora          1    0.005848
# 10                                             Notas           1    0.005848
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table8[table8['frequency']>1]
Filtro
# Out:
#                        18_sales_records  frequency  percentage  \
# 0                       sin información         61    0.356725
# 1                              En papel         47    0.274854
# 2  Software especializado + computadora         22    0.128655
# 3                            No lo hago         14    0.081871
# 4                              En Excel         10    0.058480
# 5           Caja registradora (análoga)          4    0.023392
# 6                     En Excel,En papel          4    0.023392
#
#    cumulative_perc
# 0         0.356725
# 1         0.631579
# 2         0.760234
# 3         0.842105
# 4         0.900585
# 5         0.923977
# 6         0.947368

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('18_sales_records')
Filtro_index
# Out:
#                                       frequency  percentage  cumulative_perc
# 18_sales_records
# sin información                              61    0.356725         0.356725
# En papel                                     47    0.274854         0.631579
# Software especializado + computadora         22    0.128655         0.760234
# No lo hago                                   14    0.081871         0.842105
# En Excel                                     10    0.058480         0.900585
# Caja registradora (análoga)                   4    0.023392         0.923977
# En Excel,En papel                             4    0.023392         0.947368

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ### **VARIABLE 8 : 186_internet_connection**

# %%
import pandas as pd

# Seleccionar la columna 186_internet_connection
columna_8 = Datos_limpios['186_internet_connection']

# Imprimir la columna
print(columna_8)
# Out:
# 0                  yes
# 1                  yes
# 2                  yes
# 3                  yes
# 4                  yes
#             ...
# 166    sin información
# 167    sin información
# 168    sin información
# 169    sin información
# 170    sin información
# Name: 186_internet_connection, Length: 171, dtype: object

# %%
columna_8_sin_nulos=columna_8.isnull().sum()
columna_8_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table8= freq_tbl(Datos_limpios['186_internet_connection'])
table8
# Out:
#   186_internet_connection  frequency  percentage  cumulative_perc
# 0                     yes         76    0.444444         0.444444
# 1         sin información         63    0.368421         0.812865
# 2                      no         32    0.187135         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table8[table8['frequency']>1]
Filtro
# Out:
#   186_internet_connection  frequency  percentage  cumulative_perc
# 0                     yes         76    0.444444         0.444444
# 1         sin información         63    0.368421         0.812865
# 2                      no         32    0.187135         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('186_internet_connection')
Filtro_index
# Out:
#                          frequency  percentage  cumulative_perc
# 186_internet_connection
# yes                             76    0.444444         0.444444
# sin información                 63    0.368421         0.812865
# no                              32    0.187135         1.000000

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(5,4),alpha = 0.5)
# Out:
# <Axes: xlabel='186_internet_connection'>

# %%
#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
Filtro_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ### **VARIABLE 9 : 33_credit_to_customers**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_33 = Datos_limpios['33_credit_to_customers']

# Imprimir la columna
print(columna_33)
# Out:
# 0                   no
# 1                   no
# 2                  yes
# 3                   no
# 4                  yes
#             ...
# 166    sin información
# 167    sin información
# 168    sin información
# 169    sin información
# 170    sin información
# Name: 33_credit_to_customers, Length: 171, dtype: object

# %%
columna_33_sin_nulos=columna_33.isnull().sum()
columna_33_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table9= freq_tbl(Datos_limpios['33_credit_to_customers'])
table9
# Out:
#   33_credit_to_customers  frequency  percentage  cumulative_perc
# 0                     no         80    0.467836         0.467836
# 1        sin información         64    0.374269         0.842105
# 2                    yes         27    0.157895         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table9[table9['frequency']>1]
Filtro
# Out:
#   33_credit_to_customers  frequency  percentage  cumulative_perc
# 0                     no         80    0.467836         0.467836
# 1        sin información         64    0.374269         0.842105
# 2                    yes         27    0.157895         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('33_credit_to_customers')
Filtro_index
# Out:
#                         frequency  percentage  cumulative_perc
# 33_credit_to_customers
# no                             80    0.467836         0.467836
# sin información                64    0.374269         0.842105
# yes                            27    0.157895         1.000000

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='33_credit_to_customers'>

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ### **VARIABLE 10 : 38_average_margin_profits**

# %%
import pandas as pd

# Seleccionar la columna 38_average_margin_profits
columna_10 = Datos_limpios['38_average_margin_profits']

# Imprimir la columna
print(columna_10)
# Out:
# 0      20%
# 1      20%
# 2      20%
# 3      20%
# 4      20%
#       ...
# 166    40%
# 167    40%
# 168    40%
# 169    40%
# 170    40%
# Name: 38_average_margin_profits, Length: 171, dtype: object

# %%
columna_10_sin_nulos=columna_10.isnull().sum()
columna_10_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table10= freq_tbl(Datos_limpios['38_average_margin_profits'])
table10
# Out:
#   38_average_margin_profits  frequency  percentage  cumulative_perc
# 0                       10%         43    0.251462         0.251462
# 1                       20%         25    0.146199         0.397661
# 2                     50% +         23    0.134503         0.532164
# 3                        5%         22    0.128655         0.660819
# 4                       30%         17    0.099415         0.760234
# 5                       40%         17    0.099415         0.859649
# 6                       15%         15    0.087719         0.947368
# 7                       35%          4    0.023392         0.970760
# 8                       25%          4    0.023392         0.994152
# 9                       45%          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table10[table10['frequency']>1]
Filtro
# Out:
#   38_average_margin_profits  frequency  percentage  cumulative_perc
# 0                       10%         43    0.251462         0.251462
# 1                       20%         25    0.146199         0.397661
# 2                     50% +         23    0.134503         0.532164
# 3                        5%         22    0.128655         0.660819
# 4                       30%         17    0.099415         0.760234
# 5                       40%         17    0.099415         0.859649
# 6                       15%         15    0.087719         0.947368
# 7                       35%          4    0.023392         0.970760
# 8                       25%          4    0.023392         0.994152

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('38_average_margin_profits')
Filtro_index
# Out:
#                            frequency  percentage  cumulative_perc
# 38_average_margin_profits
# 10%                               43    0.251462         0.251462
# 20%                               25    0.146199         0.397661
# 50% +                             23    0.134503         0.532164
# 5%                                22    0.128655         0.660819
# 30%                               17    0.099415         0.760234
# 40%                               17    0.099415         0.859649
# 15%                               15    0.087719         0.947368
# 35%                                4    0.023392         0.970760
# 25%                                4    0.023392         0.994152

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='38_average_margin_profits'>

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ### **VARIABLE 11 : 249_technology_training**

# %%
import pandas as pd

# Seleccionar la columna 249_technology_training
columna_249 = Datos_limpios['249_technology_training']

# Imprimir la columna
print(columna_249)
# Out:
# 0      De acuerdo
# 1      De acuerdo
# 2      De acuerdo
# 3      De acuerdo
# 4      De acuerdo
#           ...
# 166    De acuerdo
# 167    De acuerdo
# 168    De acuerdo
# 169    De acuerdo
# 170    De acuerdo
# Name: 249_technology_training, Length: 171, dtype: object

# %%
columna_249_sin_nulos=columna_249.isnull().sum()
columna_249_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table11= freq_tbl(Datos_limpios['249_technology_training'])
table11
# Out:
#           249_technology_training  frequency  percentage  cumulative_perc
# 0           Totalmente de acuerdo         79    0.461988         0.461988
# 1                      De acuerdo         62    0.362573         0.824561
# 2  Ni de acuerdo ni en desacuerdo         19    0.111111         0.935673
# 3        Totalmente en desacuerdo         10    0.058480         0.994152
# 4                   En desacuerdo          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table11[table11['frequency']>1]
Filtro
# Out:
#           249_technology_training  frequency  percentage  cumulative_perc
# 0           Totalmente de acuerdo         79    0.461988         0.461988
# 1                      De acuerdo         62    0.362573         0.824561
# 2  Ni de acuerdo ni en desacuerdo         19    0.111111         0.935673
# 3        Totalmente en desacuerdo         10    0.058480         0.994152

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('249_technology_training')
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 249_technology_training
# Totalmente de acuerdo                  79    0.461988         0.461988
# De acuerdo                             62    0.362573         0.824561
# Ni de acuerdo ni en desacuerdo         19    0.111111         0.935673
# Totalmente en desacuerdo               10    0.058480         0.994152

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='249_technology_training'>

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ### **VARIABLE 12 : 250_technology_investment_operations**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_250 = Datos_limpios['250_technology_investment_operations']

# Imprimir la columna
print(columna_250)
# Out:
# 0      En desacuerdo
# 1      En desacuerdo
# 2      En desacuerdo
# 3      En desacuerdo
# 4      En desacuerdo
#            ...
# 166    En desacuerdo
# 167    En desacuerdo
# 168    En desacuerdo
# 169    En desacuerdo
# 170    En desacuerdo
# Name: 250_technology_investment_operations, Length: 171, dtype: object

# %%
columna_250_sin_nulos=columna_250.isnull().sum()
columna_250_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table12= freq_tbl(Datos_limpios['250_technology_investment_operations'])
table12
# Out:
#   250_technology_investment_operations  frequency  percentage  cumulative_perc
# 0                Totalmente de acuerdo         58    0.339181         0.339181
# 1                           De acuerdo         54    0.315789         0.654971
# 2                        En desacuerdo         35    0.204678         0.859649
# 3       Ni de acuerdo ni en desacuerdo         13    0.076023         0.935673
# 4             Totalmente en desacuerdo         11    0.064327         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table12[table12['frequency']>1]
Filtro
# Out:
#   250_technology_investment_operations  frequency  percentage  cumulative_perc
# 0                Totalmente de acuerdo         58    0.339181         0.339181
# 1                           De acuerdo         54    0.315789         0.654971
# 2                        En desacuerdo         35    0.204678         0.859649
# 3       Ni de acuerdo ni en desacuerdo         13    0.076023         0.935673
# 4             Totalmente en desacuerdo         11    0.064327         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('250_technology_investment_operations')
Filtro_index
# Out:
#                                       frequency  percentage  cumulative_perc
# 250_technology_investment_operations
# Totalmente de acuerdo                        58    0.339181         0.339181
# De acuerdo                                   54    0.315789         0.654971
# En desacuerdo                                35    0.204678         0.859649
# Ni de acuerdo ni en desacuerdo               13    0.076023         0.935673
# Totalmente en desacuerdo                     11    0.064327         1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Invertir en tecnología para las operaciones de la empresa')
plt.xlabel('250_technology_investment_operations')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ### **VARIABLE 13 : 312_payment_of_utilities**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_13 = Datos_limpios['312_payment_of_utilities']

# Imprimir la columna
print(columna_13)
# Out:
# 0            Totalmente en desacuerdo
# 1            Totalmente en desacuerdo
# 2            Totalmente en desacuerdo
# 3            Totalmente en desacuerdo
# 4            Totalmente en desacuerdo
#                     ...
# 166    Ni de acuerdo ni en desacuerdo
# 167    Ni de acuerdo ni en desacuerdo
# 168    Ni de acuerdo ni en desacuerdo
# 169    Ni de acuerdo ni en desacuerdo
# 170    Ni de acuerdo ni en desacuerdo
# Name: 312_payment_of_utilities, Length: 171, dtype: object

# %%
columna_13_sin_nulos=columna_13.isnull().sum()
columna_13_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table13= freq_tbl(Datos_limpios['312_payment_of_utilities'])
table13
# Out:
#          312_payment_of_utilities  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo        104    0.608187         0.608187
# 1                 Algo de acuerdo         30    0.175439         0.783626
# 2           Totalmente de acuerdo         20    0.116959         0.900585
# 3  Ni de acuerdo ni en desacuerdo         12    0.070175         0.970760
# 4              Algo en desacuerdo          5    0.029240         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table13[table13['frequency']>1]
Filtro
# Out:
#          312_payment_of_utilities  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo        104    0.608187         0.608187
# 1                 Algo de acuerdo         30    0.175439         0.783626
# 2           Totalmente de acuerdo         20    0.116959         0.900585
# 3  Ni de acuerdo ni en desacuerdo         12    0.070175         0.970760
# 4              Algo en desacuerdo          5    0.029240         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('312_payment_of_utilities')
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 312_payment_of_utilities
# Totalmente en desacuerdo              104    0.608187         0.608187
# Algo de acuerdo                        30    0.175439         0.783626
# Totalmente de acuerdo                  20    0.116959         0.900585
# Ni de acuerdo ni en desacuerdo         12    0.070175         0.970760
# Algo en desacuerdo                      5    0.029240         1.000000

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(12,4),alpha = 0.5)
# Out:
# <Axes: xlabel='312_payment_of_utilities'>

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ### **VARIABLE 14 :  313_home_deliveries**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_14 = Datos_limpios['313_home_deliveries']

# Imprimir la columna
print(columna_14)
# Out:
# 0            Totalmente en desacuerdo
# 1            Totalmente en desacuerdo
# 2            Totalmente en desacuerdo
# 3            Totalmente en desacuerdo
# 4            Totalmente en desacuerdo
#                     ...
# 166    Ni de acuerdo ni en desacuerdo
# 167    Ni de acuerdo ni en desacuerdo
# 168    Ni de acuerdo ni en desacuerdo
# 169    Ni de acuerdo ni en desacuerdo
# 170    Ni de acuerdo ni en desacuerdo
# Name: 313_home_deliveries, Length: 171, dtype: object

# %%
columna_14_sin_nulos=columna_14.isnull().sum()
columna_14_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table14= freq_tbl(Datos_limpios['313_home_deliveries'])
table14
# Out:
#               313_home_deliveries  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         73    0.426901         0.426901
# 1                 Algo de acuerdo         41    0.239766         0.666667
# 2           Totalmente de acuerdo         34    0.198830         0.865497
# 3              Algo en desacuerdo         13    0.076023         0.941520
# 4  Ni de acuerdo ni en desacuerdo         10    0.058480         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table14[table14['frequency']>1]
Filtro
# Out:
#               313_home_deliveries  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         73    0.426901         0.426901
# 1                 Algo de acuerdo         41    0.239766         0.666667
# 2           Totalmente de acuerdo         34    0.198830         0.865497
# 3              Algo en desacuerdo         13    0.076023         0.941520
# 4  Ni de acuerdo ni en desacuerdo         10    0.058480         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('313_home_deliveries')
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 313_home_deliveries
# Totalmente en desacuerdo               73    0.426901         0.426901
# Algo de acuerdo                        41    0.239766         0.666667
# Totalmente de acuerdo                  34    0.198830         0.865497
# Algo en desacuerdo                     13    0.076023         0.941520
# Ni de acuerdo ni en desacuerdo         10    0.058480         1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Entregas a domicilio')
plt.xlabel('313_home_deliveries')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ### **VARIABLE 15 : 42_willingness_share_inventory_data_suppliers**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_42 = Datos_limpios['42_willingness_share_inventory_data_suppliers']

# Imprimir la columna
print(columna_42)
# Out:
# 0      Algo de acuerdo
# 1      Algo de acuerdo
# 2      Algo de acuerdo
# 3      Algo de acuerdo
# 4      Algo de acuerdo
#             ...
# 166    Algo de acuerdo
# 167    Algo de acuerdo
# 168    Algo de acuerdo
# 169    Algo de acuerdo
# 170    Algo de acuerdo
# Name: 42_willingness_share_inventory_data_suppliers, Length: 171, dtype: object

# %%
columna_42_sin_nulos=columna_42.isnull().sum()
columna_42_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table15= freq_tbl(Datos_limpios['42_willingness_share_inventory_data_suppliers'])
table15
# Out:
#   42_willingness_share_inventory_data_suppliers  frequency  percentage  \
# 0                      Totalmente en desacuerdo         94    0.549708
# 1                               Algo de acuerdo         43    0.251462
# 2                            Algo en desacuerdo         15    0.087719
# 3                         Totalmente de acuerdo         12    0.070175
# 4                Ni de acuerdo ni en desacuerdo          7    0.040936
#
#    cumulative_perc
# 0         0.549708
# 1         0.801170
# 2         0.888889
# 3         0.959064
# 4         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table15[table15['frequency']>1]
Filtro
# Out:
#   42_willingness_share_inventory_data_suppliers  frequency  percentage  \
# 0                      Totalmente en desacuerdo         94    0.549708
# 1                               Algo de acuerdo         43    0.251462
# 2                            Algo en desacuerdo         15    0.087719
# 3                         Totalmente de acuerdo         12    0.070175
# 4                Ni de acuerdo ni en desacuerdo          7    0.040936
#
#    cumulative_perc
# 0         0.549708
# 1         0.801170
# 2         0.888889
# 3         0.959064
# 4         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('42_willingness_share_inventory_data_suppliers')
Filtro_index
# Out:
#                                                frequency  percentage  \
# 42_willingness_share_inventory_data_suppliers
# Totalmente en desacuerdo                              94    0.549708
# Algo de acuerdo                                       43    0.251462
# Algo en desacuerdo                                    15    0.087719
# Totalmente de acuerdo                                 12    0.070175
# Ni de acuerdo ni en desacuerdo                         7    0.040936
#
#                                                cumulative_perc
# 42_willingness_share_inventory_data_suppliers
# Totalmente en desacuerdo                              0.549708
# Algo de acuerdo                                       0.801170
# Algo en desacuerdo                                    0.888889
# Totalmente de acuerdo                                 0.959064
# Ni de acuerdo ni en desacuerdo                        1.000000

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='42_willingness_share_inventory_data_suppliers'>

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ### **VARIABLE 16 : 185_place_orders_suppliers**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_185 = Datos_limpios['185_place_orders_suppliers']

# Imprimir la columna
print(columna_185)
# Out:
# 0      sin información
# 1      sin información
# 2      sin información
# 3      sin información
# 4      sin información
#             ...
# 166    sin información
# 167    sin información
# 168    sin información
# 169    sin información
# 170    sin información
# Name: 185_place_orders_suppliers, Length: 171, dtype: object

# %%
columna_185_sin_nulos=columna_185.isnull().sum()
columna_185_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table16= freq_tbl(Datos_limpios['185_place_orders_suppliers'])
table16
# Out:
#                            185_place_orders_suppliers  frequency  percentage  \
# 0                                     sin información        100    0.584795
# 1                                          En persona         20    0.116959
# 2              Mensajería instantánea (e.g. WhatsApp)          8    0.046784
# 3   En persona,Llamada telefónica,Mensajería insta...          7    0.040936
# 4                                  Llamada telefónica          6    0.035088
# 5   En persona,Mensajería instantánea (e.g. WhatsApp)          5    0.029240
# 6                            Página web del proveedor          5    0.029240
# 7                       En persona,Llamada telefónica          5    0.029240
# 8   Mensaje de texto (SMS),Mensajería instantánea ...          2    0.011696
# 9                 En persona,Página web del proveedor          2    0.011696
# 10                             Mensaje de texto (SMS)          2    0.011696
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table16[table16['frequency']>1]
Filtro
# Out:
#                            185_place_orders_suppliers  frequency  percentage  \
# 0                                     sin información        100    0.584795
# 1                                          En persona         20    0.116959
# 2              Mensajería instantánea (e.g. WhatsApp)          8    0.046784
# 3   En persona,Llamada telefónica,Mensajería insta...          7    0.040936
# 4                                  Llamada telefónica          6    0.035088
# 5   En persona,Mensajería instantánea (e.g. WhatsApp)          5    0.029240
# 6                            Página web del proveedor          5    0.029240
# 7                       En persona,Llamada telefónica          5    0.029240
# 8   Mensaje de texto (SMS),Mensajería instantánea ...          2    0.011696
# 9                 En persona,Página web del proveedor          2    0.011696
# 10                             Mensaje de texto (SMS)          2    0.011696
#
#     cumulative_perc
# 0          0.584795
# ...

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('185_place_orders_suppliers')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# 185_place_orders_suppliers
# sin información                                           100    0.584795
# En persona                                                 20    0.116959
# Mensajería instantánea (e.g. WhatsApp)                      8    0.046784
# En persona,Llamada telefónica,Mensajería instan...          7    0.040936
# Llamada telefónica                                          6    0.035088
# En persona,Mensajería instantánea (e.g. WhatsApp)           5    0.029240
# Página web del proveedor                                    5    0.029240
# En persona,Llamada telefónica                               5    0.029240
# Mensaje de texto (SMS),Mensajería instantánea (...          2    0.011696
# En persona,Página web del proveedor                         2    0.011696
# Mensaje de texto (SMS)                                      2    0.011696
#
# ...

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(25,4),alpha = 0.5)
# Out:
# <Axes: xlabel='185_place_orders_suppliers'>

# %% [markdown]
# ### **VARIABLE 17 : 192_procurement_planning_tools**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_17 = Datos_limpios['192_procurement_planning_tools']

# Imprimir la columna
print(columna_17)
# Out:
# 0      sin información
# 1      sin información
# 2      sin información
# 3      sin información
# 4      sin información
#             ...
# 166    sin información
# 167    sin información
# 168    sin información
# 169    sin información
# 170    sin información
# Name: 192_procurement_planning_tools, Length: 171, dtype: object

# %%
columna_17_sin_nulos=columna_17.isnull().sum()
columna_17_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table17= freq_tbl(Datos_limpios['192_procurement_planning_tools'])
table17
# Out:
#            192_procurement_planning_tools  frequency  percentage  \
# 0                         sin información        103    0.602339
# 1                                Cuaderno         25    0.146199
# 2                                 Ninguna         24    0.140351
# 3                                   Excel          6    0.035088
# 4                  Software especializado          4    0.023392
# 5               Aplicación móvil,Cuaderno          2    0.011696
# 6                          Cuaderno,Excel          2    0.011696
# 7                        Aplicación móvil          1    0.005848
# 8                             Mentalmente          1    0.005848
# 9   Cuaderno,Excel,Software especializado          1    0.005848
# 10                              catálogo           1    0.005848
# 11                         Compra directa          1    0.005848
#
#     cumulative_perc
# 0          0.602339
# 1          0.748538
# 2          0.888889
# 3          0.923977
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table17[table17['frequency']>1]
Filtro
# Out:
#   192_procurement_planning_tools  frequency  percentage  cumulative_perc
# 0                sin información        103    0.602339         0.602339
# 1                       Cuaderno         25    0.146199         0.748538
# 2                        Ninguna         24    0.140351         0.888889
# 3                          Excel          6    0.035088         0.923977
# 4         Software especializado          4    0.023392         0.947368
# 5      Aplicación móvil,Cuaderno          2    0.011696         0.959064
# 6                 Cuaderno,Excel          2    0.011696         0.970760

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('192_procurement_planning_tools')
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 192_procurement_planning_tools
# sin información                       103    0.602339         0.602339
# Cuaderno                               25    0.146199         0.748538
# Ninguna                                24    0.140351         0.888889
# Excel                                   6    0.035088         0.923977
# Software especializado                  4    0.023392         0.947368
# Aplicación móvil,Cuaderno               2    0.011696         0.959064
# Cuaderno,Excel                          2    0.011696         0.970760

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
Filtro_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ### **VARIABLE 18 : 277_payment_method_suppliers**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_277 = Datos_limpios['277_payment_method_suppliers']

# Imprimir la columna
print(columna_277)
# Out:
# 0                  sin información
# 1      Transferencia interbancaria
# 2                  sin información
# 3                  sin información
# 4                  sin información
#                   ...
# 166                sin información
# 167                sin información
# 168                sin información
# 169                sin información
# 170                sin información
# Name: 277_payment_method_suppliers, Length: 171, dtype: object

# %%
columna_277_sin_nulos=columna_277.isnull().sum()
columna_277_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table18= freq_tbl(Datos_limpios['277_payment_method_suppliers'])
table18
# Out:
#                         277_payment_method_suppliers  frequency  percentage  \
# 0                                    sin información        103    0.602339
# 1                                           Efectivo         43    0.251462
# 2               Efectivo,Transferencia interbancaria          8    0.046784
# 3                        Transferencia interbancaria          7    0.040936
# 4             Efectivo,Tarjeta de débito y/o crédito          4    0.023392
# 5                      Tarjeta de débito y/o crédito          4    0.023392
# 6  Efectivo,Tarjeta de débito y/o crédito,Transfe...          2    0.011696
#
#    cumulative_perc
# 0         0.602339
# 1         0.853801
# 2         0.900585
# 3         0.941520
# 4         0.964912
# 5         0.988304
# 6         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table18[table18['frequency']>1]
Filtro
# Out:
#                         277_payment_method_suppliers  frequency  percentage  \
# 0                                    sin información        103    0.602339
# 1                                           Efectivo         43    0.251462
# 2               Efectivo,Transferencia interbancaria          8    0.046784
# 3                        Transferencia interbancaria          7    0.040936
# 4             Efectivo,Tarjeta de débito y/o crédito          4    0.023392
# 5                      Tarjeta de débito y/o crédito          4    0.023392
# 6  Efectivo,Tarjeta de débito y/o crédito,Transfe...          2    0.011696
#
#    cumulative_perc
# 0         0.602339
# 1         0.853801
# 2         0.900585
# 3         0.941520
# 4         0.964912
# 5         0.988304
# 6         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('277_payment_method_suppliers')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# 277_payment_method_suppliers
# sin información                                           103    0.602339
# Efectivo                                                   43    0.251462
# Efectivo,Transferencia interbancaria                        8    0.046784
# Transferencia interbancaria                                 7    0.040936
# Efectivo,Tarjeta de débito y/o crédito                      4    0.023392
# Tarjeta de débito y/o crédito                               4    0.023392
# Efectivo,Tarjeta de débito y/o crédito,Transfer...          2    0.011696
#
#                                                     cumulative_perc
# 277_payment_method_suppliers
# sin información                                            0.602339
# Efectivo                                                   0.853801
# Efectivo,Transferencia interbancaria                       0.900585
# ...

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Métodos de Pago')
plt.xlabel("277_payment_method_suppliers")
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### **VARIABLE 19 : 56_procurement_changes_pandemic**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_56 = Datos_limpios['56_procurement_changes_pandemic']

# Imprimir la columna
print(columna_56)
# Out:
# 0                   no
# 1                   no
# 2                   no
# 3      sin información
# 4                  yes
#             ...
# 166    sin información
# 167    sin información
# 168    sin información
# 169    sin información
# 170    sin información
# Name: 56_procurement_changes_pandemic, Length: 171, dtype: object

# %%
columna_56_sin_nulos=columna_56.isnull().sum()
columna_56_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table19= freq_tbl(Datos_limpios['56_procurement_changes_pandemic'])
table19
# Out:
#   56_procurement_changes_pandemic  frequency  percentage  cumulative_perc
# 0                 sin información         90    0.526316         0.526316
# 1                              no         55    0.321637         0.847953
# 2                             yes         26    0.152047         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table19[table19['frequency']>1]
Filtro
# Out:
#   56_procurement_changes_pandemic  frequency  percentage  cumulative_perc
# 0                 sin información         90    0.526316         0.526316
# 1                              no         55    0.321637         0.847953
# 2                             yes         26    0.152047         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('56_procurement_changes_pandemic')
Filtro_index
# Out:
#                                  frequency  percentage  cumulative_perc
# 56_procurement_changes_pandemic
# sin información                         90    0.526316         0.526316
# no                                      55    0.321637         0.847953
# yes                                     26    0.152047         1.000000

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='56_procurement_changes_pandemic'>

# %% [markdown]
# ### **VARIABLE 20 : 157_frequency_organize_shelves**

# %%
import pandas as pd

# Seleccionar la columna 214_customer_relationship_tools
columna_157 = Datos_limpios['157_frequency_organize_shelves']

# Imprimir la columna
print(columna_157)
# Out:
# 0      Semestralmente
# 1        Semanalmente
# 2        Semanalmente
# 3        Semanalmente
# 4        Mensualmente
#             ...
# 166      Mensualmente
# 167      Mensualmente
# 168      Mensualmente
# 169      Mensualmente
# 170      Mensualmente
# Name: 157_frequency_organize_shelves, Length: 171, dtype: object

# %%
columna_157_sin_nulos=columna_157.isnull().sum()
columna_157_sin_nulos
# Out:
# 0

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table20= freq_tbl(Datos_limpios['157_frequency_organize_shelves'])
table20
# Out:
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                   Semanalmente         73    0.426901         0.426901
# 1                    Diariamente         46    0.269006         0.695906
# 2                   Mensualmente         22    0.128655         0.824561
# 3                          Nunca         16    0.093567         0.918129
# 4                 Quincenalmente         10    0.058480         0.976608
# 5                     Anualmente          2    0.011696         0.988304
# 6                 Semestralmente          1    0.005848         0.994152
# 7                    No se tiene          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table20[table20['frequency']>1]
Filtro
# Out:
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                   Semanalmente         73    0.426901         0.426901
# 1                    Diariamente         46    0.269006         0.695906
# 2                   Mensualmente         22    0.128655         0.824561
# 3                          Nunca         16    0.093567         0.918129
# 4                 Quincenalmente         10    0.058480         0.976608
# 5                     Anualmente          2    0.011696         0.988304

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('157_frequency_organize_shelves')
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 157_frequency_organize_shelves
# Semanalmente                           73    0.426901         0.426901
# Diariamente                            46    0.269006         0.695906
# Mensualmente                           22    0.128655         0.824561
# Nunca                                  16    0.093567         0.918129
# Quincenalmente                         10    0.058480         0.976608
# Anualmente                              2    0.011696         0.988304

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='157_frequency_organize_shelves'>

# %%
#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
Filtro_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>
